# %%
import yfinance as yf
import pandas as pd
import os
import matplotlib
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Untitled-1.ipynb Cell 1 line 4
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=1'>2</a> import pandas as pd
#       <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=2'>3</a> import os
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=3'>4</a> import matplotlib
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
if os.path.exists("sp500.csv"):
    sp500 = pd.read_csv("sp500.csv", index_col=0)
else:
    sp500 = yf.Ticker("^GSPC")
    sp500 = sp500.history(period="max")
    sp500.to_csv("sp500.csv")

# %%
sp500.index = pd.to_datetime(sp500.index)

# %%
sp500
# Out:
#                    Open         High          Low        Close      Volume  \
# Date
# 1950-01-03    16.660000    16.660000    16.660000    16.660000     1260000
# 1950-01-04    16.850000    16.850000    16.850000    16.850000     1890000
# 1950-01-05    16.930000    16.930000    16.930000    16.930000     2550000
# 1950-01-06    16.980000    16.980000    16.980000    16.980000     2010000
# 1950-01-09    17.080000    17.080000    17.080000    17.080000     2520000
# ...                 ...          ...          ...          ...         ...
# 2022-09-06  3930.889893  3942.550049  3886.750000  3908.189941  2209800080
# 2022-09-07  3909.429932  3987.889893  3906.030029  3979.870117           0
# 2022-09-08  3959.939941  4010.500000  3944.810059  4006.179932           0
# 2022-09-09  4022.939941  4076.810059  4022.939941  4067.360107           0
# 2022-09-12  4083.669922  4119.279785  4083.669922  4107.279785  1602969000
#
#             Dividends  Stock Splits
# Date
# 1950-01-03          0             0
# 1950-01-04          0             0
# 1950-01-05          0             0
# 1950-01-06          0             0
# 1950-01-09          0             0
# ...               ...           ...
# 2022-09-06          0             0
# 2022-09-07          0             0
# 2022-09-08          0             0
# 2022-09-09          0             0
# 2022-09-12          0             0
#
# [18292 rows x 7 columns]

# %%
sp500.plot.line(y="Close", use_index=True)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Untitled-1.ipynb Cell 5 line 1
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W4sdW50aXRsZWQ%3D?line=0'>1</a> sp500.plot.line(y="Close", use_index=True)
#
# File ~/anaconda3/envs/Crime/lib/python3.11/site-packages/pandas/plotting/_core.py:1101, in PlotAccessor.line(self, x, y, **kwargs)
#    1035 @Appender(
#    1036     """
#    1037     See Also
#    (...)
#    1093     self, x: Hashable | None = None, y: Hashable | None = None, **kwargs
#    1094 ) -> PlotAccessor:
#    1095     """
#    1096     Plot Series or DataFrame as lines.
#    1097
#    1098     This function is useful to plot lines using DataFrame's values
#    1099     as coordinates.
#    1100     """
# -> 1101     return self(kind="line", x=x, y=y, **kwargs)
#
# File ~/anaconda3/envs/Crime/lib/python3.11/site-packages/pandas/plotting/_core.py:951, in PlotAccessor.__call__(self, *args, **kwargs)
#     950 def __call__(self, *args, **kwargs):
# --> 951     plot_backend = _get_plot_backend(kwargs.pop("backend", None))
#     953     x, y, kind, kwargs = self._get_call_args(
#     954         plot_backend.__name__, self._parent, args, kwargs
#     955     )
#     957     kind = self._kind_aliases.get(kind, kind)
#
# File ~/anaconda3/envs/Crime/lib/python3.11/site-packages/pandas/plotting/_core.py:1947, in _get_plot_backend(backend)
#    1944 if backend_str in _backends:
#    1945     return _backends[backend_str]
# -> 1947 module = _load_backend(backend_str)
#    1948 _backends[backend_str] = module
#    1949 return module
#
# File ~/anaconda3/envs/Crime/lib/python3.11/site-packages/pandas/plotting/_core.py:1877, in _load_backend(backend)
#    1875         module = importlib.import_module("pandas.plotting._matplotlib")
#    1876     except ImportError:
# -> 1877         raise ImportError(
#    1878             "matplotlib is required for plotting when the "
#    1879             'default backend "matplotlib" is selected.'
#    1880         ) from None
#    1881     return module
#    1883 found_backend = False
#
# ImportError: matplotlib is required for plotting when the default backend "matplotlib" is selected.
